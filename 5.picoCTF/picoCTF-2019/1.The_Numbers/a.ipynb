# %%
from string import ascii_uppercase

# %%
ct = "16 9 3 15 3 20 6 20 8 5 14 21 13 2 5 18 19 13 1 19 15 14".split(" ")
flag = ""

for c in ct:
    flag += ascii_uppercase[int(c)-1]
print(flag[:7]+"{"+flag[7:]+"}")
# Out:
# PICOCTF{THENUMBERSMASON}
