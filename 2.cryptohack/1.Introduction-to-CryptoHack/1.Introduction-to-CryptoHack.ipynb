# %% [markdown]
# ## Finding Flags

# %% [markdown]
# Each challenge is designed to help introduce you to a new piece of cryptography. Solving a challenge will require you to find a "flag".
#
# These flags will usually be in the format crypto{y0ur_f1rst_fl4g}. The flag format helps you verify that you found the correct solution.
#
# Try submitting this flag into the form below to solve your first challenge.

# %% [markdown]
# ### Solver

# %%
print("crypto{y0ur_f1rst_fl4g}")
# Out:
# crypto{y0ur_f1rst_fl4g}

# %% [markdown]
# ## Great Snakes

# %% [markdown]
# Modern cryptography involves code, and code involves coding. CryptoHack provides a good opportunity to sharpen your skills.
#
# Of all modern programming languages, Python 3 stands out as ideal for quickly writing cryptographic scripts and attacks. For more information about why we think Python is so great for this, please see the FAQ.
#
# Run the attached Python script and it will output your flag.

# %%
#!/usr/bin/env python3

import sys
# import this

if sys.version_info.major == 2:
    print("You are running Python 2, which is no longer supported. Please update to Python 3.")

ords = [81, 64, 75, 66, 70, 93, 73, 72, 1, 92, 109, 2, 84, 109, 66, 75, 70, 90, 2, 92, 79]

print("Here is your flag:")
print("".join(chr(o ^ 0x32) for o in ords))
# Out:
# Here is your flag:
# crypto{z3n_0f_pyth0n}

# %% [markdown]
# ## ASCII

# %% [markdown]
# ASCII is a 7-bit encoding standard which allows the representation of text using the integers 0-127.
#
# Using the below integer array, convert the numbers to their corresponding ASCII characters to obtain a flag.

# %% [markdown]
# [99, 114, 121, 112, 116, 111, 123, 65, 83, 67, 73, 73, 95, 112, 114, 49, 110, 116, 52, 98, 108, 51, 125]

# %% [markdown]
# >  In Python, the chr() function can be used to convert an ASCII ordinal number to a character (the ord() function does the opposite).

# %% [markdown]
# ### Solver

# %%
ct = [99, 114, 121, 112, 116, 111, 123, 65, 83, 67, 73, 73, 95, 112, 114, 49, 110, 116, 52, 98, 108, 51, 125]
flag = "".join(chr(o) for o in ct)
print("Flag:",flag)
# Out:
# Flag: crypto{ASCII_pr1nt4bl3}

# %% [markdown]
# ### Solver Optimal

# %%
ct = [99, 114, 121, 112, 116, 111, 123, 65, 83, 67, 73, 73, 95, 112, 114, 49, 110, 116, 52, 98, 108, 51, 125]
pt = bytes(ct).decode()
print("Flag:",flag)
# Out:
# Flag: crypto{ASCII_pr1nt4bl3}

# %% [markdown]
# ## Hex

# %% [markdown]
# When we encrypt something the resulting ciphertext commonly has bytes which are not printable ASCII characters. If we want to share our encrypted data, it's common to encode it into something more user-friendly and portable across different systems.
#
# Hexadecimal can be used in such a way to represent ASCII strings. First each letter is converted to an ordinal number according to the ASCII table (as in the previous challenge). Then the decimal numbers are converted to base-16 numbers, otherwise known as hexadecimal. The numbers can be combined together, into one long hex string.
#
# Included below is a flag encoded as a hex string. Decode this back into bytes to get the flag.

# %% [markdown]
# 63727970746f7b596f755f77696c6c5f62655f776f726b696e675f776974685f6865785f737472696e67735f615f6c6f747d

# %% [markdown]
# >  In Python, the bytes.fromhex() function can be used to convert hex to bytes. The .hex() instance method can be called on byte strings to get the hex representation.

# %% [markdown]
# ### Solver

# %%
h = "63727970746f7b596f755f77696c6c5f62655f776f726b696e675f776974685f6865785f737472696e67735f615f6c6f747d"
print("Flag:",bytes.fromhex(h).decode("utf-8"))
# Out:
# Flag: crypto{You_will_be_working_with_hex_strings_a_lot}

# %% [markdown]
# ## Base64

# %% [markdown]
# Another common encoding scheme is Base64, which allows us to represent binary data as an ASCII string using an alphabet of 64 characters. One character of a Base64 string encodes 6 binary digits (bits), and so 4 characters of Base64 encode three 8-bit bytes.
#
# Base64 is most commonly used online, so binary data such as images can be easily included into HTML or CSS files.
#
# Take the below hex string, decode it into bytes and then encode it into Base64.

# %% [markdown]
# 72bca9b68fc16ac7beeb8f849dca1d8a783e8acf9679bf9269f7bf

# %% [markdown]
# > In Python, after importing the base64 module with import base64, you can use the base64.b64encode() function. Remember to decode the hex first as the challenge description states.

# %% [markdown]
# ### Solver

# %%
import base64

# %%
h = "72bca9b68fc16ac7beeb8f849dca1d8a783e8acf9679bf9269f7bf"
byte = bytes.fromhex(h)
encoded = base64.b64encode(byte)
print("Flag:",encoded.decode("utf-8"))

# flag = b'crypto/Base+64+Encoding+is+Web+Safe/'
# encoded = base64.b64decode(flag)
# h = encoded.hex()
# print(h)
# Out:
# Flag: crypto/Base+64+Encoding+is+Web+Safe/

# %% [markdown]
# ### Solver Optimal

# %%
h = "72bca9b68fc16ac7beeb8f849dca1d8a783e8acf9679bf9269f7bf"
print(base64.b64encode(bytes.fromhex(h)).decode())
# Out:
# crypto/Base+64+Encoding+is+Web+Safe/

# %% [markdown]
# ## Bytes and Big Integers

# %% [markdown]
# Cryptosystems like RSA works on numbers, but messages are made up of characters. How should we convert our messages into numbers so that mathematical operations can be applied?
#
# The most common way is to take the ordinal bytes of the message, convert them into hexadecimal, and concatenate. This can be interpreted as a base-16/hexadecimal number, and also represented in base-10/decimal.
#
# To illustrate:

# %% [markdown]
# message: HELLO
# ascii bytes: [72, 69, 76, 76, 79]
# hex bytes: [0x48, 0x45, 0x4c, 0x4c, 0x4f]
# base-16: 0x48454c4c4f
# base-10: 310400273487

# %% [markdown]
# >  Python's PyCryptodome library implements this with the methods bytes_to_long() and long_to_bytes(). You will first have to install PyCryptodome and import it with from Crypto.Util.number import *. For more details check the FAQ.

# %% [markdown]
# Convert the following integer back into a message:

# %% [markdown]
# 11515195063862318899931685488813747395775516287289682636499965282714637259206269

# %% [markdown]
# ### Solver

# %%
from Crypto.Util.number import *

# %%
ct = 11515195063862318899931685488813747395775516287289682636499965282714637259206269
print("Flag:",long_to_bytes(ct).decode("utf-8"))
# Out:
# Flag: crypto{3nc0d1n6_4ll_7h3_w4y_d0wn}

# %% [markdown]
# ### Solver Optimal

# %%
ct = 11515195063862318899931685488813747395775516287289682636499965282714637259206269
pt = ct.to_bytes((ct.bit_length()+7)//8,"big")
print("Flag:",pt.decode())
# Out:
# Flag: crypto{3nc0d1n6_4ll_7h3_w4y_d0wn}

# %% [markdown]
# ## XOR Starter

# %% [markdown]
# XOR is a bitwise operator which returns 0 if the bits are the same, and 1 otherwise. In textbooks the XOR operator is denoted by ⊕, but in most challenges and programming languages you will see the caret ^ used instead.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# For longer binary numbers we XOR bit by bit: 0110 ^ 1010 = 1100. We can XOR integers by first converting the integer from decimal to binary. We can XOR strings by first converting each character to the integer representing the Unicode character.
#
# Given the string label, XOR each character with the integer 13. Convert these integers back to a string and submit the flag as crypto{new_string}.

# %% [markdown]
# > The Python pwntools library has a convenient xor() function that can XOR together data of different types and lengths. But first, you may want to implement your own function to solve this.

# %% [markdown]
# ### Solver

# %%
pt = "label"
ct = "".join(chr(ord(char) ^ 13) for char in pt)
flag = "crypto{"+ct+"}"
print("Flag:",flag)
# Out:
# Flag: crypto{aloha}

# %% [markdown]
# ### Optimal Solver

# %%
pt = "label"
ct = pt.encode("utf-8")
res = bytes(b^13 for b in ct).decode()
flag = "crypto{"+res+"}"
print(flag)
# Out:
# crypto{aloha}

# %% [markdown]
# ## XOR Properties

# %% [markdown]
# In the last challenge, you saw how XOR worked at the level of bits. In this one, we're going to cover the properties of the XOR operation and then use them to undo a chain of operations that have encrypted a flag. Gaining an intuition for how this works will help greatly when you come to attacking real cryptosystems later, especially in the block ciphers category.
#
# There are four main properties we should consider when we solve challenges using the XOR operator

# %% [markdown]
# Commutative: A ⊕ B = B ⊕ A
# Associative: A ⊕ (B ⊕ C) = (A ⊕ B) ⊕ C
# Identity: A ⊕ 0 = A
# Self-Inverse: A ⊕ A = 0

# %% [markdown]
# Let's break this down. Commutative means that the order of the XOR operations is not important. Associative means that a chain of operations can be carried out without order (we do not need to worry about brackets). The identity is 0, so XOR with 0 "does nothing", and lastly something XOR'd with itself returns zero.
#
# Let's put this into practice! Below is a series of outputs where three random keys have been XOR'd together and with the flag. Use the above properties to undo the encryption in the final line to obtain the flag.

# %% [markdown]
# KEY1 = a6c8b6733c9b22de7bc0253266a3867df55acde8635e19c73313
# KEY2 ^ KEY1 = 37dcb292030faa90d07eec17e3b1c6d8daf94c35d4c9191a5e1e
# KEY2 ^ KEY3 = c1545756687e7573db23aa1c3452a098b71a7fbf0fddddde5fc1
# FLAG ^ KEY1 ^ KEY3 ^ KEY2 = 04ee9855208a2cd59091d04767ae47963170d1660df7f56f5faf

# %% [markdown]
# >  Before you XOR these objects, be sure to decode from hex to bytes.

# %% [markdown]
# ### Solver

# %%
def xor(n1: bytes,n2: bytes):
    result = b""
    for i,_ in enumerate(n1):
        result += (n1[i]^n2[i]).to_bytes(1,"big")
    return result

# %%
FLAG = xor(bytes.fromhex("a6c8b6733c9b22de7bc0253266a3867df55acde8635e19c73313"),xor(bytes.fromhex("04ee9855208a2cd59091d04767ae47963170d1660df7f56f5faf"),bytes.fromhex("c1545756687e7573db23aa1c3452a098b71a7fbf0fddddde5fc1")))
print("FLAG:",FLAG.decode("utf-8"))
# Out:
# FLAG: crypto{x0r_i5_ass0c1at1v3}

# %% [markdown]
# ### Optimal Solver

# %%
def bxor(a: bytes, b: bytes):
    return bytes(x ^ y for x,y in zip(a,b))

# %%
KEY1 = bytes.fromhex("a6c8b6733c9b22de7bc0253266a3867df55acde8635e19c73313")
KEY2xorKEY3 = bytes.fromhex("c1545756687e7573db23aa1c3452a098b71a7fbf0fddddde5fc1")
XOR_all = bytes.fromhex("04ee9855208a2cd59091d04767ae47963170d1660df7f56f5faf")
FLAG = bxor(XOR_all,bxor(KEY1,KEY2xorKEY3))
print("Flag:",FLAG.decode())
# Out:
# Flag: crypto{x0r_i5_ass0c1at1v3}

# %% [markdown]
# ## Favourite byte

# %% [markdown]
# For the next few challenges, you'll use what you've just learned to solve some more XOR puzzles.
#
# I've hidden some data using XOR with a single byte, but that byte is a secret. Don't forget to decode from hex first.

# %% [markdown]
# 73626960647f6b206821204f21254f7d694f7624662065622127234f726927756d

# %% [markdown]
# ### Solver

# %%
def xor(n1: bytes,n2: bytes):
    result = b""
    for i,_ in enumerate(n1):
        result += (n1[i]^n2[i]).to_bytes(1,"big")
    return result

# %%
ct = "73626960647f6b206821204f21254f7d694f7624662065622127234f726927756d"
byte = bytes.fromhex(ct)
pt = ""

for i in range(256):
    key = i.to_bytes(1,"big") * len(byte)
    pt += (xor(key, byte)).decode("utf-8")
    if "crypto" in pt:
        print("Flag was XOR with",hex(i))
        break
    pt = ""
print("FLAG:",pt)
# Out:
# Flag was XOR with 0x10
# FLAG: crypto{0x10_15_my_f4v0ur173_by7e}

# %% [markdown]
# ### Optimal Solver

# %%
# kita tau awalan flag = c dari "crypto{"
# jadi c xor key = p
# key = c xor p
ct = bytes.fromhex("73626960647f6b206821204f21254f7d694f7624662065622127234f726927756d")
key = ct[0] ^ ord("c")
pt = bytes((c ^ key) for c in ct)
print("Flag:",pt.decode())
# Out:
# Flag: crypto{0x10_15_my_f4v0ur173_by7e}

# %% [markdown]
# ## You either know, XOR you don't

# %% [markdown]
# I've encrypted the flag with my secret key, you'll never be able to guess it.
#
# > Remember the flag format and how it might help you in this challenge!

# %% [markdown]
# 0e0b213f26041e480b26217f27342e175d0e070a3c5b103e2526217f27342e175d0e077e263451150104

# %% [markdown]
# ### Solver

# %%
def xor(n1: bytes,n2: bytes):
    result = b""
    for i,_ in enumerate(n1):
        result += (n1[i]^n2[i]).to_bytes(1,"big")
    return result

# %%
ct = "0e0b213f26041e480b26217f27342e175d0e070a3c5b103e2526217f27342e175d0e077e263451150104"
byte = bytes.fromhex(ct)

hint = b"crypto{1"
key = b""
pt = b""

while(len(key) != len(hint)):
    for i in range(255):
        cand = xor(i.to_bytes(1,"big"), byte[len(key)].to_bytes(1,"big"))
        if cand == hint[len(key)].to_bytes(1,"big"):
            key += i.to_bytes(1,"big")
            break

print("key:",key)
i = 0
for c in byte:
    pt += xor(c.to_bytes(1,"big"),key[i].to_bytes(1,"big"))
    i = (i + 1) % len(key)

print("Flag:",pt.decode("utf-8"))
# Out:
# key: b'myXORkey'
# Flag: crypto{1f_y0u_Kn0w_En0uGH_y0u_Kn0w_1t_4ll}

# %% [markdown]
# ### Optimal Solver

# %%
ct = bytes.fromhex("0e0b213f26041e480b26217f27342e175d0e070a3c5b103e2526217f27342e175d0e077e263451150104")
hint = b"crypto{1"
key = bytes(c ^ k for c,k in zip(ct[:len(hint)], hint))
# Out:
# b'myXORkey'

# %%
from itertools import cycle
pt = bytes(c ^ k for c,k in zip(ct,cycle(key)))
print("Flag:",pt.decode())
# Out:
# Flag: crypto{1f_y0u_Kn0w_En0uGH_y0u_Kn0w_1t_4ll}
