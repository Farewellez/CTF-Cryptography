# %% [markdown]
# ## Modular Exponentiation

# %% [markdown]
# #### known

# %%
b = 101
e = 17
m = 22663

# %% [markdown]
# #### python3 script

# %%
print(pow(b,e,m))

# %% [markdown]
# ## Public Keys

# %%
# The most common value for e is 0x10001 or 65537
p = 17
q = 23
N = p*q
e = 65537
b = 12

print(pow(b,e,N))
# print(pow(b,e,p))
# print(pow(b,e,q))

# %% [markdown]
# ## Euler's Totient

# %%
from math import gcd

# %%
p = 857504083339712752489993810777
q = 1029224947942998075080348647219
N = p*q
print(N)

# %%
assert q*p == N
phi_N = (p-1)*(q-1)
print(phi_N)

# %% [markdown]
# ## Private Keys

# %%
p = 857504083339712752489993810777
q = 1029224947942998075080348647219
e = 65537

# %%
assert p*q == N

N = p*q
phi_N = (p-1)*(q-1)
d = pow(e,-1,phi_N)
print(d)

# %% [markdown]
# ## RSA Decryption

# %% [markdown]
# #### known

# %%
N = 882564595536224140639625987659416029426239230804614613279163
c = 77578995801157823671636298847186723593814843845525223303932
e = 65537

# %% [markdown]
# #### sage script

# %%
N = 882564595536224140639625987659416029426239230804614613279163
factors = factor(N)
print(factors)

# $ docker run --rm -u root -v $(pwd):/app -w /app sagemath/sagemath sage a.sage
# 857504083339712752489993810777 * 1029224947942998075080348647219

# %% [markdown]
# #### python3 script

# %%
p = 857504083339712752489993810777
q = 1029224947942998075080348647219
assert p*q == N

phi_N = (p-1)*(q-1)
d = pow(e,-1,phi_N)

m = pow(c,d,N)
print(m)

# %% [markdown]
# ## RSA Signatures

# %%
from hashlib import sha256
from Crypto.Util.number import bytes_to_long

# %%
N = ...
d = ...

# %%
m = "crypto{Immut4ble_m3ssag1ng}".encode()
hash_m = sha256(m).digest()

S = pow(bytes_to_long(hash_m), d, N)
print(S)

# %% [markdown]
# ## Factoring

# %% [markdown]
# #### sage script

# %%
N = 510143758735509025530880200653196460532653147
factors = factor(N)
print(factors)

# $ docker run --rm -u root -v $(pwd):/app -w /app sagemath/sagemath sage a.sage
# 19704762736204164635843 * 25889363174021185185929

# %% [markdown]
# #### python3 script

# %%
N = 510143758735509025530880200653196460532653147
p = 19704762736204164635843
q = 25889363174021185185929
assert p*q == N

print(min(p,q))

# %%
# https://en.wikipedia.org/wiki/General_number_field_sieve
print(N.bit_count() <= pow(10,100))

# %% [markdown]
# ## Monoprime

# %% [markdown]
# #### known

# %%
n =                                                                  
e = 65537
ct = 

# %% [markdown]
# #### sage script

# %%
# https://crypto.stackexchange.com/questions/5170/why-do-we-need-in-rsa-the-modulus-to-be-product-of-2-primes
N = 
factors = factor(N)
print(factors)

# $ docker run --rm -u root -v $(pwd):/app -w /app sagemath/sagemath sage a.sage
# 

# %% [markdown]
# #### python3 script

# %%
from Crypto.Util.number import long_to_bytes

# %%
one_prime_product = 
phi_N = one_prime_product - 1

d = pow(e,-1,phi_N)
m = pow(ct,d,n)
flag = long_to_bytes(m)
print(flag.decode())

# %% [markdown]
# ## Manyprime

# %% [markdown]
# #### known

# %%
n = ...
e = 65537
ct = ...

# %% [markdown]
# #### sage script

# %%
# https://doc.sagemath.org/html/en/reference/interfaces/sage/interfaces/ecm.html
N = ...
factors = ecm.factor(N)
print(factors)

# $ docker run --rm -u root -v $(pwd):/app -w /app sagemath/sagemath sage a.sage
# [9282105380008121879, 9303850685953812323, 9389357739583927789, 10336650220878499841, 10638241655447339831, 11282698189561966721, 11328768673634243077, 11403460639036243901, 11473665579512371723, 11492065299277279799, 11530534813954192171, 11665347949879312361, 12132158321859677597, 12834461276877415051, 12955403765595949597, 12973972336777979701, 13099895578757581201, 13572286589428162097, 14100640260554622013, 14178869592193599187, 14278240802299816541, 14523070016044624039, 14963354250199553339, 15364597561881860737, 15669758663523555763, 15824122791679574573, 15998365463074268941, 16656402470578844539, 16898740504023346457, 17138336856793050757, 17174065872156629921, 17281246625998849649]

# %% [markdown]
# #### python3 script

# %%
# https://www.researchgate.net/publication/353922862_Study_of_Multi-Prime_RSA
factors = [9282105380008121879, 9303850685953812323, 9389357739583927789, 10336650220878499841, 10638241655447339831, 11282698189561966721, 11328768673634243077, 11403460639036243901, 11473665579512371723, 11492065299277279799, 11530534813954192171, 11665347949879312361, 12132158321859677597, 12834461276877415051, 12955403765595949597, 12973972336777979701, 13099895578757581201, 13572286589428162097, 14100640260554622013, 14178869592193599187, 14278240802299816541, 14523070016044624039, 14963354250199553339, 15364597561881860737, 15669758663523555763, 15824122791679574573, 15998365463074268941, 16656402470578844539, 16898740504023346457, 17138336856793050757, 17174065872156629921, 17281246625998849649]
phi_N = 1
for p in factors:
    phi_N *= (p - 1)

d = pow(e,-1,phi_N)
m = pow(ct,d,n)
flag = long_to_bytes(m)
print(flag.decode())

# %% [markdown]
# ## Salty

# %% [markdown]
# #### known

# %%
n =                                                                   
e = 1
ct = 44981230718212183604274785925793145442655465025264554046028251311164494127485

# %% [markdown]
# #### chall.py

# %%
#!/usr/bin/env python3

from Crypto.Util.number import getPrime, inverse, bytes_to_long, long_to_bytes

e = 1
d = -1

while d == -1:
    p = getPrime(512)
    q = getPrime(512)
    phi = (p - 1) * (q - 1)
    d = inverse(e, phi)

n = p * q

flag = b"XXXXXXXXXXXXXXXXXXXXXXX"
pt = bytes_to_long(flag)
ct = pow(pt, e, n)

print(f"n = {n}")
print(f"e = {e}")
print(f"ct = {ct}")

pt = pow(ct, d, n)
decrypted = long_to_bytes(pt)
assert decrypted == flag

# %%
from Crypto.Util.number import long_to_bytes

# %%
# https://crypto.stackexchange.com/questions/109/rsa-with-small-exponents
# c = m**e mod n
# c = m**1 mod n
# c = m mod n
# c mod n = m
# m = c mod n

m = ct % n
flag = long_to_bytes(m)
print(flag.decode())

# %% [markdown]
# ## Modulus Inutilis

# %% [markdown]
# #### known

# %%
n = ...
e = 3
ct = 243251053617903760309941844835411292373350655973075480264001352919865180151222189820473358411037759381328642957324889519192337152355302808400638052620580409813222660643570085177957

# %% [markdown]
# #### chall.py

# %%
#!/usr/bin/env python3

from Crypto.Util.number import getPrime, inverse, bytes_to_long, long_to_bytes

e = 3
d = -1

while d == -1:
    p = getPrime(1024)
    q = getPrime(1024)
    phi = (p - 1) * (q - 1)
    d = inverse(e, phi)

n = p * q

flag = b"XXXXXXXXXXXXXXXXXXXXXXX"
pt = bytes_to_long(flag)
ct = pow(pt, e, n)

print(f"n = {n}")
print(f"e = {e}")
print(f"ct = {ct}")

pt = pow(ct, d, n)
decrypted = long_to_bytes(pt)
assert decrypted == flag

# %% [markdown]
# #### python3 script

# %%
from Crypto.Util.number import long_to_bytes

# %%
print(ct.bit_count())
print(n.bit_count())
assert ct.bit_count() < n.bit_count()
# Out:
# 304
# 1032

# %%
# https://math.stackexchange.com/questions/1961603/nth-root-of-huge-integer-number-in-sage
# https://doc.sagemath.org/html/en/reference/functions/sage/functions/other.html#sage.functions.other.Function_real_nth_root

ct = 243251053617903760309941844835411292373350655973075480264001352919865180151222189820473358411037759381328642957324889519192337152355302808400638052620580409813222660643570085177957
root = real_nth_root(ct,3)
print(root)

# $ docker run --rm -u root -v $(pwd):/app -w /app sagemath/sagemath sage a.sage
# 624239975241694158443315202759206900318542905782320965248893

# %%
m = 624239975241694158443315202759206900318542905782320965248893
flag = long_to_bytes(m).decode()
print(flag)
# Out:
# crypto{N33d_m04R_p4dd1ng}

# %% [markdown]
# ## Working with Fields

# %%
p=991
g=209
d = pow(g,-1,p)
print(d)
# Out:
# 569

# %% [markdown]
# ## Generators of Groups

# %% [markdown]
# #### sage script

# %%
# https://doc.sagemath.org/html/en/reference/finite_rings/sage/rings/finite_rings/finite_field_base.html
p=28151
k = GF(p)
pe = k.multiplicative_generator()
print(pe)

# $ docker run --rm -u root -v $(pwd):/app -w /app sagemath/sagemath sage a.sage
# 7

# %% [markdown]
# ## Computing Public Values

# %%
g= 2
p= ...
a= ...

# %%
print(pow(g,a,p))
# Out:
# ...

# %% [markdown]
# ## Computing Shared Secrets

# %%
from Crypto.Util.number import long_to_bytes

# %%
g= 2
p= ...
A= ...

# %%
b= ...
B= ...

assert pow(g,b,p) == B

# %%
my_shared_secret = pow(A,b,p)
print(my_shared_secret)
# Out:
# ...

# %% [markdown]
# ## Deriving Symmetric Keys

# %% [markdown]
# #### source code

# %%
from Crypto.Cipher import AES
from Crypto.Util.Padding import pad, unpad
import hashlib
import os
from secret import shared_secret

FLAG = b'crypto{????????????????????????????}'


def encrypt_flag(shared_secret: int):
    # Derive AES key from shared secret
    sha1 = hashlib.sha1()
    sha1.update(str(shared_secret).encode('ascii'))
    key = sha1.digest()[:16]

    # Encrypt flag
    iv = os.urandom(16)
    cipher = AES.new(key, AES.MODE_CBC, iv)
    ciphertext = cipher.encrypt(pad(FLAG, 16))

    # Prepare data to send
    data = {}
    data['iv'] = iv.hex()
    data['encrypted_flag'] = ciphertext.hex()
    return data


print(encrypt_flag(shared_secret))

# %%
g= 2
p= ...

# %%
A= ...

b= ...
B= ...

# %%
iv= '737561146ff8194f45290f5766ed6aba' 
encrypted_flag= '39c99bf2f0c14678d6a5416faef954b5893c316fc3c48622ba1fd6a9fe85f3dc72a29c394cf4bc8aff6a7b21cae8e12c'

# %% [markdown]
# #### decrypt.py

# %%
from Crypto.Cipher import AES
from Crypto.Util.Padding import pad, unpad
import hashlib


def is_pkcs7_padded(message):
    padding = message[-message[-1]:]
    return all(padding[i] == len(padding) for i in range(0, len(padding)))


def decrypt_flag(shared_secret: int, iv: str, ciphertext: str):
    # Derive AES key from shared secret
    sha1 = hashlib.sha1()
    sha1.update(str(shared_secret).encode('ascii'))
    key = sha1.digest()[:16]
    
    # Decrypt flag
    ciphertext = bytes.fromhex(ciphertext)
    iv = bytes.fromhex(iv)
    cipher = AES.new(key, AES.MODE_CBC, iv)
    plaintext = cipher.decrypt(ciphertext)

    if is_pkcs7_padded(plaintext):
        return unpad(plaintext, 16).decode('ascii')
    else:
        return plaintext.decode('ascii')


shared_secret = pow(A, b, p)
iv = iv
ciphertext = encrypted_flag

print(decrypt_flag(shared_secret, iv, ciphertext))
# Out:
# crypto{sh4r1ng_s3cret5_w1th_fr13nd5}

# %% [markdown]
# ## Parameter Injection

# %%
import json
from pwn import *
from pprint import pprint

# %%
host = "socket.cryptohack.org"
port = 13371 
context.log_level = 'debug'
# context.log_level = 'error'

# %%
io = remote(host,port)

io.recvuntil(b'Intercepted from Alice: ')
alice_public_data = io.recvline()
spoofed_alice_pub = json.loads(alice_public_data.decode())

spoofed_alice_pub['A'] = "0x1"
payload_alice_pub = spoofed_alice_pub

io.recvuntil(b'Send to Bob: ')
io.sendline(json.dumps(payload_alice_pub).encode())

io.recvuntil(b'Intercepted from Bob: ')
bob_public_data = io.recvline()
spoofed_bob_pub = json.loads(bob_public_data.decode())

spoofed_bob_pub['B'] = "0x1"
payload_bob_pub = spoofed_bob_pub
io.recvuntil(b'Send to Alice: ')
io.sendline(json.dumps(payload_bob_pub).encode())

io.recvuntil(b'Intercepted from Alice: ')
ct_data = io.recvline()
final_data = json.loads(ct_data.decode())

io.close()
# Out:
# [x] Opening connection to socket.cryptohack.org on port 13371
# [x] Opening connection to socket.cryptohack.org on port 13371: Trying 134.122.111.232
# [+] Opening connection to socket.cryptohack.org on port 13371: Done
# [DEBUG] Received 0x18 bytes:
#     b'Intercepted from Alice: '
# [DEBUG] Received 0x331 bytes:
# ...

# %%
g = int(spoofed_alice_pub['g'],16)
p = int(spoofed_alice_pub['p'],16)
iv = final_data['iv']
encrypted_flag = final_data['encrypted_flag']

print(f"A = {A}")
print(f"g = {g}")
print(f"p = {p}")
print(f"iv = {iv}")
print(f"p = {p}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 A = int(data['A'],16)
#       2 g = int(data['g'],16)
#       3 p = int(data['p'],16)
#       4 iv = data['iv']
#
# KeyError: 'A'
